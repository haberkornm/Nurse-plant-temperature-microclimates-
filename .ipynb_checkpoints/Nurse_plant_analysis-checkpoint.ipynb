# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('nurse_plant_temperatures_all_locations.csv', index_col = 0)

# %%
df.time = pd.to_datetime(df.time)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77946 entries, 5 to 3997
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   time      77946 non-null  datetime64[ns]
#  1   temp      77946 non-null  float64
#  2   sensor    77946 non-null  object
#  3   plant     77946 non-null  object
#  4   location  77946 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 3.6+ MB

# %%
df['month'] = df.time.dt.month
df['hour'] = df.time.dt.hour 
df['minute'] = df.time.dt.minute

# %%
df.minute.value_counts()
# Out:
# minute
# 0     66790
# 30    11155
# 20        1
# Name: count, dtype: int64

# %%
df = pd.DataFrame(df[df.minute == 0])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66790 entries, 5 to 3997
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   time      66790 non-null  datetime64[ns]
#  1   temp      66790 non-null  float64
#  2   sensor    66790 non-null  object
#  3   plant     66790 non-null  object
#  4   location  66790 non-null  object
#  5   month     66790 non-null  int32
#  6   hour      66790 non-null  int32
#  7   minute    66790 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(3), object(3)
# memory usage: 3.8+ MB

# %%
df.drop(columns = 'minute', inplace = True)

# %%
df.reset_index(drop = True, inplace = True)

# %%
total_mean_df = df.groupby(['plant', 'hour']).temp.mean().reset_index()

# %%
means_df = df.groupby('plant').temp.mean().reset_index()
means_df.rename(columns = {'temp' : 'mean_temp'}, inplace = True)

# %%
total_df = total_mean_df.merge(means_df, left_on = 'plant', right_on = 'plant')
total_df['adjusted_mean'] = total_df.temp - total_df.mean_temp

# %%
total_df.head()
# Out:
#           plant  hour       temp  mean_temp  adjusted_mean
# 0  A. deltoidea     0  18.965978  22.105414      -3.139436
# 1  A. deltoidea     1  18.389043  22.105414      -3.716371
# 2  A. deltoidea     2  17.790569  22.105414      -4.314846
# 3  A. deltoidea     3  17.249237  22.105414      -4.856177
# 4  A. deltoidea     4  16.675694  22.105414      -5.429720

# %%
plt.plot(total_df[total_df.plant == 'A. deltoidea'].hour, total_df[total_df.plant == 'A. deltoidea'].adjusted_mean, label = 'A. deltoidea')
plt.plot(total_df[total_df.plant == 'L. tridentata'].hour, total_df[total_df.plant == 'L. tridentata'].adjusted_mean, label = 'L. tridentata')
plt.plot(total_df[total_df.plant == 'O. tesota'].hour, total_df[total_df.plant == 'O. tesota'].adjusted_mean, label = 'O. tesota')
plt.plot(total_df[total_df.plant == 'P. microphylla'].hour, total_df[total_df.plant == 'P. microphylla'].adjusted_mean, label = 'P. microphylla')
plt.plot(total_df[total_df.plant == 'open'].hour, total_df[total_df.plant == 'open'].adjusted_mean, label = 'open')
plt.legend()
plt.grid()
plt.ylabel('Temperature change from mean Degrees C')
plt.xlabel('Hour of Day')
plt.title('Nurse Plant Daily Microclimate Temperatures')
plt.show()

# %%
temp_df = pd.DataFrame(df[df.plant != 'open'])
open_df = pd.DataFrame(df[df.plant == 'open'])
open_df.drop(columns = ['month', 'hour', 'plant', 'sensor'], inplace = True)
open_df.rename(columns = {'temp' : 'open_temp'}, inplace = True)

# %%
#merged_df = 
temp_df.merge(open_df, left_on = ['time', 'location'], right_on = ['time', 'location'])
# Out:
#                       time  temp sensor          plant              location  \
# 0      2023-01-02 16:00:00  12.2  ltri1  L. tridentata          black canyon
# 1      2023-01-02 16:00:00  12.2  ltri1  L. tridentata          black canyon
# 2      2023-01-02 17:00:00  11.1  ltri1  L. tridentata          black canyon
# 3      2023-01-02 17:00:00  11.1  ltri1  L. tridentata          black canyon
# 4      2023-01-02 18:00:00   9.9  ltri1  L. tridentata          black canyon
# ...                    ...   ...    ...            ...                   ...
# 146693 2022-06-08 22:00:00  36.2    iw3      O. tesota  White Tank Mountains
# 146694 2022-06-08 23:00:00  35.3    iw3      O. tesota  White Tank Mountains
# 146695 2022-06-08 23:00:00  35.3    iw3      O. tesota  White Tank Mountains
# 146696 2022-06-09 00:00:00  34.6    iw3      O. tesota  White Tank Mountains
# 146697 2022-06-09 00:00:00  34.6    iw3      O. tesota  White Tank Mountains
#
#         month  hour  open_temp
# 0           1    16       13.4
# 1           1    16       13.8
# 2           1    17       11.5
# 3           1    17       11.9
# 4           1    18        9.9
# ...       ...   ...        ...
# 146693      6    22       36.3
# 146694      6    23       34.7
# 146695      6    23       35.1
# 146696      6     0       33.8
# 146697      6     0       34.3
#
# [146698 rows x 8 columns]

# %%
merged_df.temp - merged_df.open_temp
# Out:
# 0        -1.2
# 1        -1.6
# 2        -0.4
# 3        -0.8
# 4         0.0
#          ...
# 146722   -0.1
# 146723    0.6
# 146724    0.2
# 146725    0.8
# 146726    0.3
# Length: 146727, dtype: float64

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146727 entries, 0 to 146726
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   time       146727 non-null  datetime64[ns]
#  1   temp       146727 non-null  float64
#  2   sensor     146727 non-null  object
#  3   plant      146727 non-null  object
#  4   location   146727 non-null  object
#  5   month      146727 non-null  int32
#  6   hour       146727 non-null  int32
#  7   open_temp  146698 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int32(2), object(3)
# memory usage: 7.8+ MB

# %%
merged_df.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146698 entries, 0 to 146726
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   time       146698 non-null  datetime64[ns]
#  1   temp       146698 non-null  float64
#  2   sensor     146698 non-null  object
#  3   plant      146698 non-null  object
#  4   location   146698 non-null  object
#  5   month      146698 non-null  int32
#  6   hour       146698 non-null  int32
#  7   open_temp  146698 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int32(2), object(3)
# memory usage: 9.0+ MB

# %%
merged_df[merged_df.open_temp.isna()].location.value_counts()
# Out:
# location
# wickenburg          26
# Cottonwood Creek     3
# Name: count, dtype: int64

# %%
merged_df[(merged_df.open_temp.isna()) & (merged_df.location == 'wickenburg')]
# Out:
#                       time  temp  sensor           plant    location  month  \
# 46362  2022-02-12 13:30:00  24.2  adelt1    A. deltoidea  wickenburg      2
# 46363  2022-02-12 14:00:00  23.2  adelt1    A. deltoidea  wickenburg      2
# 49300  2022-02-27 23:30:00  14.0  adelt1    A. deltoidea  wickenburg      2
# 49301  2022-02-28 00:00:00  13.9  adelt1    A. deltoidea  wickenburg      2
# 52294  2000-01-01 00:20:00  22.8  adelt2    A. deltoidea  wickenburg      1
# 52295  2022-02-12 13:00:00  26.7  adelt2    A. deltoidea  wickenburg      2
# 52296  2022-02-12 14:00:00  22.1  adelt2    A. deltoidea  wickenburg      2
# 53769  2022-02-27 23:00:00  14.4  adelt2    A. deltoidea  wickenburg      2
# 53770  2022-02-28 00:00:00  13.9  adelt2    A. deltoidea  wickenburg      2
# 55251  2022-02-12 13:30:00  24.3  adelt3    A. deltoidea  wickenburg      2
# 55252  2022-02-12 14:00:00  23.7  adelt3    A. deltoidea  wickenburg      2
# 58189  2022-02-27 23:30:00  14.2  adelt3    A. deltoidea  wickenburg      2
# 58190  2022-02-28 00:00:00  14.0  adelt3    A. deltoidea  wickenburg      2
# 61183  2022-02-12 14:00:00  22.9  adelt4    A. deltoidea  wickenburg      2
# 64124  2022-02-28 00:00:00  13.6  adelt4    A. deltoidea  wickenburg      2
# 67129  2022-02-12 14:00:00  29.1   ltri1   L. tridentata  wickenburg      2
# 70070  2022-02-28 00:00:00  13.3   ltri1   L. tridentata  wickenburg      2
# 73075  2022-02-12 14:00:00  27.0   ltri2   L. tridentata  wickenburg      2
# 76016  2022-02-28 00:00:00  13.3   ltri2   L. tridentata  wickenburg      2
# 84957  2022-03-15 16:30:00  25.3   ltri3   L. tridentata  wickenburg      3
# 90906  2022-02-12 13:00:00  24.9     pv1  P. microphylla  wickenburg      2
# 90907  2022-02-12 13:30:00  25.6     pv1  P. microphylla  wickenburg      2
# 90908  2022-02-12 14:00:00  25.1     pv1  P. microphylla  wickenburg      2
# 93841  2022-02-27 23:00:00  14.2     pv1  P. microphylla  wickenburg      2
# 93842  2022-02-27 23:30:00  13.9     pv1  P. microphylla  wickenburg      2
# 93843  2022-02-28 00:00:00  13.9     pv1  P. microphylla  wickenburg      2
# 96848  2022-02-12 13:00:00  21.2     pv2  P. microphylla  wickenburg      2
# 96849  2022-02-12 13:30:00  21.8     pv2  P. microphylla  wickenburg      2
# 96850  2022-02-12 14:00:00  21.5     pv2  P. microphylla  wickenburg      2
# 99783  2022-02-27 23:00:00  14.1     pv2  P. microphylla  wickenburg      2
# 99784  2022-02-27 23:30:00  13.9     pv2  P. microphylla  wickenburg      2
# 99785  2022-02-28 00:00:00  13.7     pv2  P. microphylla  wickenburg      2
# 102790 2022-02-12 13:30:00  27.9     pv3  P. microphylla  wickenburg      2
# 102791 2022-02-12 14:00:00  24.3     pv3  P. microphylla  wickenburg      2
# 105728 2022-02-27 23:30:00  13.7     pv3  P. microphylla  wickenburg      2
# 105729 2022-02-28 00:00:00  13.6     pv3  P. microphylla  wickenburg      2
# 108722 2022-02-12 13:30:00  24.0     pv4  P. microphylla  wickenburg      2
# 108723 2022-02-12 14:00:00  23.3     pv4  P. microphylla  wickenburg      2
# 111660 2022-02-27 23:30:00  14.2     pv4  P. microphylla  wickenburg      2
# 111661 2022-02-28 00:00:00  14.0     pv4  P. microphylla  wickenburg      2
#
#         hour  open_temp
# 46362     13        NaN
# 46363     14        NaN
# 49300     23        NaN
# 49301      0        NaN
# 52294      0        NaN
# 52295     13        NaN
# 52296     14        NaN
# 53769     23        NaN
# 53770      0        NaN
# 55251     13        NaN
# 55252     14        NaN
# 58189     23        NaN
# 58190      0        NaN
# 61183     14        NaN
# 64124      0        NaN
# 67129     14        NaN
# 70070      0        NaN
# 73075     14        NaN
# 76016      0        NaN
# 84957     16        NaN
# 90906     13        NaN
# 90907     13        NaN
# 90908     14        NaN
# 93841     23        NaN
# 93842     23        NaN
# 93843      0        NaN
# 96848     13        NaN
# 96849     13        NaN
# 96850     14        NaN
# 99783     23        NaN
# 99784     23        NaN
# 99785      0        NaN
# 102790    13        NaN
# 102791    14        NaN
# 105728    23        NaN
# 105729     0        NaN
# 108722    13        NaN
# 108723    14        NaN
# 111660    23        NaN
# 111661     0        NaN
